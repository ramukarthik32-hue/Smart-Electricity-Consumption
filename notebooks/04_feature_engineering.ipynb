# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../dataset/electricity_consumption_cleaned.csv")

print("Cleaned dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Cleaned dataset loaded successfully!
# Shape: (19735, 29)

# %%
df["date"] = pd.to_datetime(df["date"])

print("Date converted successfully!")
print(df["date"].dtype)
# Out:
# Date converted successfully!
# datetime64[us]

# %%
df["hour"] = df["date"].dt.hour
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["day_of_week"] = df["date"].dt.dayofweek

print("Time features created successfully!")

print(
    df[
        ["date", "hour", "day", "month", "day_of_week"]
    ].head()
)
# Out:
# Time features created successfully!
#                  date  hour  day  month  day_of_week
# 0 2016-01-11 17:00:00    17   11      1            0
# 1 2016-01-11 17:10:00    17   11      1            0
# 2 2016-01-11 17:20:00    17   11      1            0
# 3 2016-01-11 17:30:00    17   11      1            0
# 4 2016-01-11 17:40:00    17   11      1            0

# %%
df["is_weekend"] = (
    df["day_of_week"] >= 5
).astype(int)

print("Weekend feature created!")

print(
    df["is_weekend"].value_counts()
)
# Out:
# Weekend feature created!
# is_weekend
# 0    14263
# 1     5472
# Name: count, dtype: int64

# %%
df = df.drop(columns=["date"])

print("Original date column removed.")
print("New shape:", df.shape)
# Out:
# Original date column removed.
# New shape: (19735, 33)

# %%
print("Columns after feature engineering:")

for column in df.columns:
    print(column)
# Out:
# Columns after feature engineering:
# Appliances
# lights
# T1
# RH_1
# T2
# RH_2
# T3
# RH_3
# T4
# RH_4
# T5
# RH_5
# T6
# RH_6
# T7
# RH_7
# T8
# RH_8
# T9
# RH_9
# T_out
# Press_mm_hg
# RH_out
# Windspeed
# Visibility
# Tdewpoint
# rv1
# rv2
# hour
# day
# month
# day_of_week
# is_weekend

# %%
X = df.drop(columns=["Appliances"])
y = df["Appliances"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (19735, 32)
# Target shape: (19735,)

# %%
print("Feature data types:")

print(X.dtypes)
# Out:
# Feature data types:
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# hour             int32
# day              int32
# month            int32
# day_of_week      int32
# is_weekend       int64
# dtype: object

# %%
print("Missing values in features:")
print(X.isnull().sum().sum())

print("\nMissing values in target:")
print(y.isnull().sum())
# Out:
# Missing values in features:
# 0
#
# Missing values in target:
# 0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (15788, 32)
# Testing data: (3947, 32)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed!")
print("Scaled training shape:", X_train_scaled.shape)
print("Scaled testing shape:", X_test_scaled.shape)
# Out:
# Feature scaling completed!
# Scaled training shape: (15788, 32)
# Scaled testing shape: (3947, 32)

# %%
X_train_scaled_df = pd.DataFrame(
    X_train_scaled,
    columns=X_train.columns
)

X_test_scaled_df = pd.DataFrame(
    X_test_scaled,
    columns=X_test.columns
)

print("Scaled DataFrames created successfully!")

display(X_train_scaled_df.head())
# Out:
# Scaled DataFrames created successfully!
#     lights        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0 -0.47829 -1.117535  1.322565 -0.521432  1.145891 -0.936016  1.553528
# 1 -0.47829  2.409418  1.590438  2.524617  0.392577  2.456153  0.590126
# 2 -0.47829  0.504076  1.052165  0.540967  0.531300 -0.152313  1.635181
# 3 -0.47829 -1.179665 -0.557603 -1.432060  0.124030 -0.831411 -0.642372
# 4 -0.47829 -0.676407 -1.257611 -1.477591 -0.157043 -0.985827 -0.692699
#
#          T4      RH_4        T5  ...  Windspeed  Visibility  Tdewpoint  \
# 0 -0.855218  1.767774 -1.127855  ...   1.424184   -1.255203   0.992041
# 1  1.875073  1.511362  1.945969  ...  -0.286316   -1.241097   2.273160
# 2  0.558683  0.327863 -0.269346  ...   1.629444    0.141283  -0.852294
# 3 -1.201379 -0.472943 -0.707005  ...  -1.244196    0.874791  -0.606383
# 4 -0.660197 -1.050447 -0.755634  ...  -0.970516   -0.366530  -1.359982
#
#         rv1       rv2      hour       day     month  day_of_week  is_weekend
# 0  0.979912  0.979912  0.072446  1.175638 -1.565296    -1.000445   -0.622078
# 1  1.245757  1.245757  0.793894  1.294137  1.413058     0.509259   -0.622078
# 2  1.173907  1.173907  0.216736 -1.549856 -0.820708    -0.497210   -0.622078
# 3 -0.855721 -0.855721 -0.360422 -1.312857 -0.076119     1.012494    1.607516
# 4 -0.974162 -0.974162 -1.081870 -0.364859 -0.076119     1.515729    1.607516
#
# [5 rows x 32 columns]

# %%
print("========== FEATURE ENGINEERING SUMMARY ==========")

print("Original dataset rows:", len(df))

print("Number of features:", X.shape[1])

print("Training samples:", len(X_train))

print("Testing samples:", len(X_test))

print("Target column: Appliances")

print("\nFeature engineering completed successfully!")
# Out:
# ========== FEATURE ENGINEERING SUMMARY ==========
# Original dataset rows: 19735
# Number of features: 32
# Training samples: 15788
# Testing samples: 3947
# Target column: Appliances
#
# Feature engineering completed successfully!
